# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Content
#
# * Libraries
# * Data loading
# * Metadata dataframe analysis
# * EDA

# %% [markdown]
# ## Libraries

# %%
# Libreries
import numpy as np
import pandas as pd
import functions as mf
import matplotlib as plt
import plotly.graph_objects as go
import plotly.express as px

# Libreries settings
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Data loading

# %%
# Metada revision
metadata = pd.read_csv(r'C:\Users\mauva\OneDrive\Documents\ITAM\9no Semestre\MINERIA Y ANALISIS DE DATOS\REPOSITORIO_PROYECTO\Skin_Cancer_Detection_Project\DATA\isic-2024-challenge\train-metadata.csv')
# Out:
# C:\Users\mauva\AppData\Local\Temp\ipykernel_10488\667497558.py:2: DtypeWarning:
#
# Columns (51,52) have mixed types. Specify dtype option on import or set low_memory=False.

# %% [markdown]
# ## Metadata dataframe analysis

# %%
# Univariate analysis
pd.DataFrame(mf.univar_analisis(metadata))
# Out:
#                         Variable DataType   Total  No Missings  Missings  \
# 0                        isic_id   object  401059       401059         0
# 1                         target    int64  401059       401059         0
# 2                     patient_id   object  401059       401059         0
# 3                     age_approx  float64  401059       398261      2798
# 4                            sex   object  401059       389542     11517
# 5            anatom_site_general   object  401059       395303      5756
# 6         clin_size_long_diam_mm  float64  401059       401059         0
# 7                     image_type   object  401059       401059         0
# 8                  tbp_tile_type   object  401059       401059         0
# 9                       tbp_lv_A  float64  401059       401059         0
# 10                   tbp_lv_Aext  float64  401059       401059         0
# 11                      tbp_lv_B  float64  401059       401059         0
# ...

# %% [markdown]
# ## EDA
